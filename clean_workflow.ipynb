# %%
from backend import *

# %%
splits, mapping = parse_file("data.txt")
linkage_matrix = construct_linkage_matrix(splits, mapping)
labels, height, num_clusters = find_optimal_clusters(linkage_matrix)
species_data, clusters_data = get_clusters_rich_info(labels, mapping)

# %%
species_data
# Out:
#                      index  cluster
# tip
# Brown Bear               0        1
# Polar Bear               1        1
# American Black Bear      2        1
# Sun Bear                 3        1
# Sloth Bear               4        1
# Asiatic Black Bear       5        1
# Spectacled Bear          6        2
# Giant Panda              7        3

# %%
clusters_data
# Out:
#                 tips  num_tips
# cluster
# 1        0,1,2,3,4,5         6
# 2                  6         1
# 3                  7         1

# %%
plot_dendrogram(linkage_matrix, mapping, num_clusters = num_clusters)
